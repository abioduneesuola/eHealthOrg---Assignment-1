# %% [markdown]
# #### Hello, and welcome  to the project. I am Abiodun Eesuola.
#
# Let's start

# %% [markdown]
# To complete this assignment, I might follow this sequence:
#
# | Task | To do | Tool |
# |------|------|------|
# | 1 | Transform `LGA_SEN_Districts.xls` → Structured Table | Python (pandas) or OpenRefine |
# | 2 | Load & Join All Datasets | Python + GeoPandas |
# | 3 | Link Health Facilities to Senatorial Districts | Spatial & Attribute Join |
# | 4 | Find Best-Ranked Facility per Senatorial District | Pandas Aggregation |
# | 5 | Export Final Data to SQLite | SQLAlchemy / sqlite3 |
# | 6 | Create Map in QGIS | QGIS + Print Layout (A3 PDF) |
# | 7 | Package Deliverables | Folder structure + Training Slide |

# %% [markdown]
# ##### Objective:
#
# - Transform by means of automation, the document ‘LGA_SEN_Districts’ into a well-structured database table that anyone can easily work with.
#
# - Export all final (processed) datasets in an SQLite database
#
# - Make a map in QGIS showing the senatorial districts, highlighting health facilities with the best scores.
#
# - Include the necessary map elements and export map in PDF and on A3 paper size.
#
# **I will deliver:**
#
# -> A well-structured table output from (1) above
#
# -> The automation script or ETL tool used to generate (i) above
#
# -> An SQLite database containing the spatial datasets I will be using for the map
#
# -> A QGIS project showing the datasets and map
#
# -> An A3 size exported PDF map of Nigeria senatorial districts showing health facilities ranking based on availability of personnel
#
# -> A training slide for my team on how the process can be done.
#
# Let's go!

# %% [markdown]
# #### Task 1
# ---
# **At first glance, the file is stored as an .xls file. This is an old-school format. I will convert the file to an .xlsx file instead, while retaining all content. I achieved this using an online tool. The new file is saved as "LGA_SEN_Districts.xlsx" in the same folder.**
#
# Next, I'll inspect the data to see it's structure and how to work with  it.

# %%
import pandas as pd

# Reading my file while automatically dropping empty rows and duplicates to perform initial cleaning.
df = pd.read_excel(r"c:\Users\USER\Desktop\eHealthOrg\Assignment 1\LGA_SEN_Districts.xlsx").dropna(how = "all").drop_duplicates()
display(df.head(50))
# Out:
#    NAME OF SENATORIAL DISTRICTS                   Unnamed: 1 Unnamed: 2  \
# 1                          ABIA                          NaN        NaN
# 2                           S/N  NAME OF SENATORIAL DISTRICT       CODE
# 3                             1                  ABIA NORTH   SD/001/AB
# 4                             2                ABIA CENTRAL   SD/002/AB
# 5                             3                  ABIA SOUTH   SD/003/AB
# 7                     AKWA IBOM                          NaN        NaN
# 9                             7         AKWA IBOM NORTH EAST  SD/007/AK
# 10                            8        AKWA IBOM NORTH WEST   SD/008/AK
# 11                            9             AKWA IBOM SOUTH   SD/009/AK
# 14                          NaN                          NaN        NaN
# 15                            4                ADAMAWA NORTH  SD/004/AD
# 16                            5               ADAMAWA SOUTH   SD/005/AD
# 17                            6              ADAMAWA CENTRAL  SD/006/AD
# 21                     ANAMBRA                           NaN        NaN
# 23                           10               ANAMBRA NORTH   SD/010/AN
# 24                           11             ANAMBRA CENTRAL   SD/011/AN
# 25                           12               ANAMBRA SOUTH   SD/012/AN
# 27                       BAUCHI                          NaN        NaN
# 29                           13                BAUCHI SOUTH   SD/013/BA
# 30                           14              BAUCHI CENTRAL   SD/014/BA
# 31                           15                BAUCHI NORTH   SD/015/BA
# 34                      BAYELSA                          NaN        NaN
# 36                           16                 BAYELSA EAST  SD/016/BY
# 37                           17             BAYELSA CENTRAL   SD/017/BY
# 38                           18                BAYELSA WEST   SD/018/BY
# 44                          NaN                          NaN        NaN
# 46                           19           BENUE NORTH  EAST   SD/019/BN
# 47                           20             BENUE NORTH WEST  SD/020/BN
# 48                           21                  BENUE SOUTH  SD/021/BN
# 51                        BORNO                          NaN        NaN
# 53                           22                  BORNO NORTH  SD/022/BO
# 54                           23                BORNO CENTRAL  SD/023/BO
# 55                           24                  BORNO SOUTH  SD/024/BO
# 57                  CROSS RIVER                          NaN        NaN
# 59                           25            CROSS RIVER NORTH  SD/025/CR
# 60                           26          CROSS RIVER CENTRAL  SD/026/CR
# 61                           27            CROSS RIVER SOUTH  SD/027/CR
# 64                        DELTA                          NaN        NaN
# 66                           28                DELTA CENTRAL  SD/028/DT
# 67                           29                  DELTA NORTH  SD/029/DT
# 68                           30                  DELTA SOUTH  SD/030/DT
# 69                       EBONYI                          NaN        NaN
# 71                           31                 EBONYI NORTH  SD/031/EB
# 72                           32               EBONYI CENTRAL  SD/032/EB
# 73                           33                EBONYI  SOUTH  SD/033/EB
# 74                          EDO                          NaN        NaN
# 76                           34                  EDO CENTRAL  SD/034/ED
# 77                           35                    EDO NORTH  SD/035/ED
# 78                           36                   EDO  SOUTH  SD/036/ED
# 80                        EKITI                          NaN        NaN
#
#                                            Unnamed: 3  \
# 1                                                 NaN
# 2                                         COMPOSITION
# 3     UMUNNEOCHI, ISUKWUATO, OHAFIA, AROCHUKWU, BENDE
# 4   UMUAHIA NORTH, UMUAHIA SOUTH, IKWUANO, ISIALA ...
# 5   ABA NORTH, ABA SOUTH, UGWUNAGBO, OBINGWA,  UKW...
# 7                                                 NaN
# 9   ETINAN, IBESIKPO ASUTAN, IBIONO IBOM, ITU, NSI...
# 10  ABAK, ESSIEN UDIM, ETIM EKPO, IKA, IKONO, IKOT...
# 11  EASTERN OBOLO, EKET, ESIT EKET, IBENO, IKOT AB...
# 14                                            ADAMAWA
# 15  MADAGALI, MAIHA, MICHIKA, MUBI NORTH, MUBI SOUTH
# 16  DEMSA, GANYE, GUYUK, JADA, MAYO-BELWA, NUMAN, ...
# 17  HONG, FUFORE, SONG, YOLA NORTH, YOLA SOUTH, GERFI
# 21                                                NaN
# 23  ONITSHA NORTH, ONITSHA SOUTH, OYI, OGBARU, ANA...
# 24  AWKA NORTH, AWKA SOUTH, NJIKOKA, ANAOCHA, IDEM...
# 25  IHIALA, NNEWI NORTH, NNEWI SOUTH, ORUMBA SOUTH...
# 27                                                NaN
# 29  ALKALERI, KIRFI, BAUCHI, TAFAWA BALEWA, BOGORO...
# 30       NINGI, WARJI, DARAZO, GANJUWA, MISAU, DAMBAN
# 31  ZAKI, GAMAWA, JAMA’ARE, ITAS-GADAU, SHIRA, GIA...
# 34                                                NaN
# 36                                BRASS, NEMBE, OGBIA
# 37           KOLOKUMA/OPOKUMA, SOUTHERN IJAW, YENAGOA
# 38                                  EKEREMOR, SAGBAMA
# 44                                              BENUE
# 46  KATSINA-ALA, KONSHISHA, KWANDE, LOGO, UKUM, US...
# 47  BURUKU, GBOKO, GUMA, GWER-EAST, GWER-WEST, MAR...
# 48  ADO, AGATU, APA, OBI, OGBADIBO, OHIMINI, OJU,O...
# 51                                                NaN
# 53  ABADAM, GUBIO, GUZAMALA,  KUKAWA, MAGUMERI, MA...
# 54  DIKWA, JERE, KALA BALGE, MAFA, METROPOLITAN, N...
# 55  ASKIRA/UBA, BAYO, BIU, CHIBOK, DAMABOA, GWOZA,...
# 57                                                NaN
# 59      BEKWARRA, OBANLIKU, OBUDU, OGOJA, YALA, BIASE
# 60             ABI, BOKI, ETUNG, IKOM, OBUBRA, YAKURR
# 61  CALABAR MUNICIPAL, CALABAR SOUTH, AKAMKPA, AKP...
# 64                                                NaN
# 66  ETHIOPE EAST, ETHIOPE WEST, OKPE, SAPELE,UDU, ...
# 67  ANIOCHA NORTH, ANIOCHA SOUTH, IKA NORTH-EAST, ...
# 68  BOMADI, BURUTU, ISOKO NORTH, ISOKO SOUTH, PATA...
# 69                                                NaN
# 71                   ABAKALIKI, EBONYI, IZZI, OHAUKWU
# 72              EZZA NORTH, EZZA SOUTH, IKWO, ISHIELU
# 73  AFIKPO NORTH, AFIKPO SOUTH, IVO, OHAOZARA, ONICHA
# 74                                                NaN
# 76  ESAN CENTRAL, ESAN NORTH EAST, ESAN SOUTH EAST...
# 77  AKOKO EDO, ETSAKO EAST, ETSAKO CENTRAL, ETSAKO...
# 78  OREDO, ORHIONMWON, OVIA NORTH EAST, OVIA SOUTH...
# 80                                                NaN
#
#                               Unnamed: 4
# 1                                    NaN
# 2               NAME OF COLLATION CENTRE
# 3           COUNCIL HALL OHAFIA LGA HQS
# 4     COUNCIL HALL UMUAHIA NORTH LGA HQS
# 5            ABA TOWN HALL ABA SOUTH LGA
# 7                                    NaN
# 9                    INEC OFFICE UYO LGA
# 10            INEC OFFICE IKOT EKPENELGA
# 11                  EKET LGA INEC OFFICE
# 14                                   NaN
# 15                              GSS MUBI
# 16                             GSS NUMAN
# 17                             GMMC YOLA
# 21                                   NaN
# 23              ONITHA NORTH INEC OFFICE
# 24                            AWKA SOUTH
# 25               NNEWI NORTH INEC OFFICE
# 27                                   NaN
# 29                     INEC STATE OFFICE
# 30                                DARAZO
# 31                                 AZARE
# 34                                   NaN
# 36                            INEC BRASS
# 37                  COUNCIL HALL YENAGOA
# 38                   INEC OFFICE SAGBAMA
# 44                                   NaN
# 46                           KATSINA-ALA
# 47                              MARKURDI
# 48                                OTUKPO
# 51                                   NaN
# 53                   INEC OFFICE MONGUNO
# 54    WAZIRI HALL MADUGURI METRO COUNCIL
# 55                BIU LG COUNCIL CHAMBER
# 57                                   NaN
# 59                     INEC OFFICE OGOJA
# 60                      INEC OFFICE IKOM
# 61                   CALABAR INEC OFFICE
# 64                                   NaN
# 66          TOWN HALL, UGHELLI NORTH LGA
# 67                 INEC STATE H/QS ASABA
# 68         ISOKO SOUTH COUNCIL HALL OLEH
# 69                                   NaN
# 71    ABAKALIKI LGA COUNCIL HALL NKALIKI
# 72     LG COUNCIL HALL ONUEKE EZZA SOUTH
# 73  AFIKPO NORTH LGA COUNCIL HALL AFIKPO
# 74                                   NaN
# 76           SACRED HEART GIRLS’S UBIAJA
# 77                   COUNCIL HALL, AUCHI
# 78                  INEC H/Q, BENIN CITY
# 80                                   NaN

# %% [markdown]
# I see a pattern here.
#
# 1. Rows like **`ABIA`**, **`AKWA IBOM`**, **`ADAMAWA`**, etc. are **state names**, as seen right from the first row.
#
#    * They appear in column `"NAME OF SENATORIAL DISTRICTS"`.
#    * The other columns are empty on those rows.
#
# 2. The second row in the dataframe is a **header row** (`S/N, NAME OF SENATORIAL DISTRICT, CODE, COMPOSITION, NAME OF COLLATION CENTRE`).
#
# 3. After that come the **actual senatorial district rows** (`1, ABIA NORTH, SD/001/AB, ...`).
#
#
# To clean this dataset into something usable, I need to:
#
# - **Forward-fill state names** (so each senatorial district row inherits the correct state).
# - **Ignore repeated header rows** (`S/N`, etc.).
# - **Persistently drop empty rows** (like the NaN-only ones).
# - **Rename the useful columns** to something like:
#
# ```python
# ["serial", "district", "code", "composition", "collation_centre", "state"]
# ```

# %%
import pandas as pd

# Load Excel (no header, so we can control cleaning)
df = pd.read_excel(
    r"c:\Users\USER\Desktop\eHealthOrg\Assignment 1\LGA_SEN_Districts.xlsx",
    header=None
)

# Rename temporary columns
df.columns = ["col1", "col2", "col3", "col4", "col5"]

# Detect rows that are state names (all caps words, not numeric, not "S/N")
state_rows = df["col1"].fillna("").str.strip()
df["state"] = df["col1"].where(
    state_rows.str.match(r"^[A-Z ]+$") & ~state_rows.str.contains("S/N", na=False)
)

# Forward-fill state names correctly
df["state"] = df["state"].ffill()

# Keep only rows where col1 is numeric → the districts
mask = df["col1"].fillna("").astype(str).str.isnumeric()
clean_df = df[mask].copy()

# Rename columns to meaningful names
clean_df = clean_df.rename(columns={
    "col2": "senatorial_district",
    "col3": "code",
    "col4": "composition",
    "col5": "collation_centre"
})

# Keep final useful columns
clean_df = clean_df[["state", "senatorial_district", "code", "composition", "collation_centre"]]

# I'm saving the cleaned files as both a csv and an Excel file for versatility, so anyone can easily work with it
clean_df.to_csv(r"c:\Users\USER\Desktop\eHealthOrg\Assignment 1\cleaned_LGA_SEN.csv", index=False)
clean_df.to_excel(r"c:\Users\USER\Desktop\eHealthOrg\Assignment 1\cleaned_LGA_SEN.xlsx", index=False)

# Summary: number of districts per state
summary = clean_df.groupby("state")["senatorial_district"].count().reset_index()
summary = summary.rename(columns={"senatorial_district": "num_districts"})

display(clean_df.head(), clean_df.tail())
# Out:
#         state    senatorial_district       code  \
# 4        ABIA            ABIA NORTH   SD/001/AB
# 5        ABIA          ABIA CENTRAL   SD/002/AB
# 6        ABIA            ABIA SOUTH   SD/003/AB
# 10  AKWA IBOM   AKWA IBOM NORTH EAST  SD/007/AK
# 11  AKWA IBOM  AKWA IBOM NORTH WEST   SD/008/AK
#
#                                           composition  \
# 4     UMUNNEOCHI, ISUKWUATO, OHAFIA, AROCHUKWU, BENDE
# 5   UMUAHIA NORTH, UMUAHIA SOUTH, IKWUANO, ISIALA ...
# 6   ABA NORTH, ABA SOUTH, UGWUNAGBO, OBINGWA,  UKW...
# 10  ETINAN, IBESIKPO ASUTAN, IBIONO IBOM, ITU, NSI...
# 11  ABAK, ESSIEN UDIM, ETIM EKPO, IKA, IKONO, IKOT...
#
#                       collation_centre
# 4         COUNCIL HALL OHAFIA LGA HQS
# 5   COUNCIL HALL UMUAHIA NORTH LGA HQS
# 6          ABA TOWN HALL ABA SOUTH LGA
# 10                 INEC OFFICE UYO LGA
# 11          INEC OFFICE IKOT EKPENELGA
#        state        senatorial_district        code  \
# 243     YOBE                 YOBE SOUTH   SD/105/YB
# 248  ZAMFARA              ZAMFARA NORTH   SD/106/ZF
# 249  ZAMFARA            ZAMFARA CENTRAL   SD/107/ZF
# 250  ZAMFARA               ZAMFARA WEST   SD/108/ZF
# 261      FCT  FEDERAL CAPITAL TERRITORY  SD/109/FCT
#
#                                            composition  \
# 243            FIKA, FUNE, NANGERE, POTISKUM, DAMATURU
# 248  K/NAMODA, SHINKAFI, ZURMI, BIRNIN MAGAJI, T/MA...
# 249                        GUSAU, TSAFE, BUNGUDU, MARU
# 250             MARADUN, BAKURA, ANKA, BUKKUYUM, GUMMI
# 261  ABAJI AREA COUNCIL, GWAGWA AREA COUNCIL, KUJE ...
#
#                  collation_centre
# 243  FEDERAL COLLEGE OF EDUCATION
# 248      INEC OFFICE KAURA NAMODA
# 249             INEC OFFICE GUSAU
# 250     INEC OFFICE TALATA MAFARA
# 261               INEC OFFICE FCT

# %% [markdown]
# Now our dataframe looks tidy!
#
# ---
# **But looks can be deceiving. I will double-check manually to make sure everything is as it should be. First I'll check how many senatorial districts there are for each state.**

# %%
print("Summary of senatorial districts per state:\n")
display(summary)
# Out:
# Summary of senatorial districts per state:
#           state  num_districts
# 0      ANAMBRA               3
# 1          ABIA              3
# 2     AKWA IBOM              6
# 3        BAUCHI              3
# 4       BAYELSA              6
# 5         BORNO              3
# 6   CROSS RIVER              3
# 7         DELTA              3
# 8        EBONYI              3
# 9           EDO              3
# 10        EKITI              3
# 11        ENUGU              3
# 12          FCT              1
# 13        GOMBE              3
# 14          IMO              3
# 15       JIGAWA              3
# 16       KADUNA              3
# 17         KANO              3
# 18      KATSINA              3
# 19        KEBBI              3
# 20         KOGI              3
# 21        KWARA              3
# 22        LAGOS              6
# 23        NIGER              3
# 24         OGUN              3
# 25         ONDO              3
# 26         OSUN              3
# 27          OYO              3
# 28      PLATEAU              3
# 29       RIVERS              3
# 30       SOKOTO              3
# 31       TARABA              3
# 32         YOBE              3
# 33      ZAMFARA              3

# %% [markdown]
# We see above that some states have 6 senatorial districts instead of 3. Let's take a microscopic look at the data

# %%
# Show all rows and columns
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

display(clean_df)
# Out:
#            state        senatorial_district        code  \
# 4           ABIA                ABIA NORTH    SD/001/AB
# 5           ABIA              ABIA CENTRAL    SD/002/AB
# 6           ABIA                ABIA SOUTH    SD/003/AB
# 10     AKWA IBOM       AKWA IBOM NORTH EAST   SD/007/AK
# 11     AKWA IBOM      AKWA IBOM NORTH WEST    SD/008/AK
# 12     AKWA IBOM           AKWA IBOM SOUTH    SD/009/AK
# 16     AKWA IBOM              ADAMAWA NORTH   SD/004/AD
# 17     AKWA IBOM             ADAMAWA SOUTH    SD/005/AD
# 18     AKWA IBOM            ADAMAWA CENTRAL   SD/006/AD
# 24      ANAMBRA              ANAMBRA NORTH    SD/010/AN
# 25      ANAMBRA            ANAMBRA CENTRAL    SD/011/AN
# 26      ANAMBRA              ANAMBRA SOUTH    SD/012/AN
# 30        BAUCHI              BAUCHI SOUTH    SD/013/BA
# 31        BAUCHI            BAUCHI CENTRAL    SD/014/BA
# 32        BAUCHI              BAUCHI NORTH    SD/015/BA
# 37       BAYELSA               BAYELSA EAST   SD/016/BY
# 38       BAYELSA           BAYELSA CENTRAL    SD/017/BY
# 39       BAYELSA              BAYELSA WEST    SD/018/BY
# 47       BAYELSA         BENUE NORTH  EAST    SD/019/BN
# 48       BAYELSA           BENUE NORTH WEST   SD/020/BN
# 49       BAYELSA                BENUE SOUTH   SD/021/BN
# 54         BORNO                BORNO NORTH   SD/022/BO
# 55         BORNO              BORNO CENTRAL   SD/023/BO
# 56         BORNO                BORNO SOUTH   SD/024/BO
# 60   CROSS RIVER          CROSS RIVER NORTH   SD/025/CR
# 61   CROSS RIVER        CROSS RIVER CENTRAL   SD/026/CR
# 62   CROSS RIVER          CROSS RIVER SOUTH   SD/027/CR
# 67         DELTA              DELTA CENTRAL   SD/028/DT
# 68         DELTA                DELTA NORTH   SD/029/DT
# 69         DELTA                DELTA SOUTH   SD/030/DT
# 72        EBONYI               EBONYI NORTH   SD/031/EB
# 73        EBONYI             EBONYI CENTRAL   SD/032/EB
# 74        EBONYI              EBONYI  SOUTH   SD/033/EB
# 77           EDO                EDO CENTRAL   SD/034/ED
# 78           EDO                  EDO NORTH   SD/035/ED
# 79           EDO                 EDO  SOUTH   SD/036/ED
# 83         EKITI                EKITI NORTH   SD/037/EK
# 84         EKITI              EKITI CENTRAL   SD/038/EK
# 85         EKITI               EKITI  SOUTH   SD/039/EK
# 90         ENUGU                 ENUGU EAST   SD/040/EN
# 91         ENUGU                 ENUGU WEST   SD/041/EN
# 92         ENUGU               ENUGU  NORTH   SD/042/EN
# 97         GOMBE              GOMBE CENTRAL   SD/043/GM
# 98         GOMBE                GOMBE SOUTH   SD/044/GM
# 99         GOMBE              GOMBE NORTH     SD/045/GM
# 109          IMO                   IMO EAST   SD/046/IM
# 110          IMO                   IMO WEST   SD/047/IM
# 111          IMO                IMO NORTH     SD/048/IM
# 116       JIGAWA        JIGAWA SOUTH – WEST   SD/049/JG
# 117       JIGAWA        JIGAWA NORTH – EAST   SD/050/JG
# 118       JIGAWA       JIGAWA NORTH - WEST    SD/051/JG
# 126       KADUNA               KADUNA NORTH   SD/052/KD
# 127       KADUNA             KADUNA CENTRAL   SD/053/KD
# 128       KADUNA               KADUNA SOUTH   SD/054/KD
# 134         KANO               KANO CENTRAL   SD/055/KN
# 135         KANO                 KANO NORTH   SD/056/KN
# 136         KANO                KANO  SOUTH   SD/057/KN
# 147      KATSINA              KATSINA NORTH   SD/058/KT
# 148      KATSINA              KATSINA SOUTH   SD/059/KT
# 149      KATSINA           KATSINA CENTRAL    SD/060/KT
# 153        KEBBI                KEBBI NORTH   SD/061/KB
# 154        KEBBI              KEBBI CENTRAL   SD/062/KB
# 155        KEBBI                KEBBI SOUTH   SD/063/KB
# 158         KOGI               KOGI CENTRAL   SD/064/KG
# 159         KOGI                  KOGI EAST   SD/065/KG
# 160         KOGI                  KOGI WEST   SD/066/KG
# 165        KWARA                KWARA NORTH   SD/067/KW
# 166        KWARA              KWARA CENTRAL   SD/068/KW
# 167        KWARA                KWARA SOUTH   SD/069/KW
# 171        LAGOS              LAGOS CENTRAL   SD/070/LA
# 172        LAGOS                 LAGOS EAST   SD/071/LA
# 173        LAGOS                LAGOS  WEST   SD/072/LA
# 177        LAGOS            NASSARAWA NORTH   SD/073/NW
# 178        LAGOS             NASSARAWA WEST   SD/074/NW
# 179        LAGOS           NASSARAWA  SOUTH   SD/075/NW
# 185        NIGER                 NIGER EAST   SD/076/NG
# 186        NIGER                NIGER NORTH   SD/077/NG
# 187        NIGER                NIGER SOUTH   SD/078/NG
# 191         OGUN               OGUN CENTRAL   SD/079/OG
# 192         OGUN                  OGUN EAST   SD/080/OG
# 193         OGUN                  OGUN WEST   SD/081/OG
# 196         ONDO                 ONDO NORTH   SD/082/OD
# 197         ONDO               ONDO CENTRAL   SD/083/OD
# 198         ONDO                 ONDO SOUTH   SD/084/OD
# 202         OSUN               OSUN CENTRAL   SD/085/OS
# 203         OSUN                  OSUN EAST   SD/086/OS
# 204         OSUN                  OSUN WEST   SD/087/OS
# 210          OYO                OYO CENTRAL   SD/088/OY
# 211          OYO                  OYO NORTH   SD/089/OY
# 212          OYO                  OYO SOUTH   SD/090/OY
# 218      PLATEAU              PLATEAU SOUTH   SD/091/PL
# 219      PLATEAU            PLATEAU CENTRAL   SD/092/PL
# 220      PLATEAU              PLATEAU NORTH   SD/093/PL
# 224       RIVERS                RIVERS EAST   SD/094/RV
# 225       RIVERS          RIVERS SOUTH EAST   SD/095/RV
# 226       RIVERS                RIVERS WEST   SD/096/RV
# 229       SOKOTO                SOKOTO EAST   SD/097/SO
# 230       SOKOTO               SOKOTO NORTH   SD/098/SO
# 231       SOKOTO               SOKOTO SOUTH   SD/099/SO
# 235       TARABA               TARABA SOUTH   SD/100/TR
# 236       TARABA             TARABA CENTRAL   SD/101/TR
# 237       TARABA               TARABA NORTH   SD/102/TR
# 241         YOBE                  YOBE EAST   SD/103/YB
# 242         YOBE                 YOBE NORTH   SD/104/YB
# 243         YOBE                 YOBE SOUTH   SD/105/YB
# 248      ZAMFARA              ZAMFARA NORTH   SD/106/ZF
# 249      ZAMFARA            ZAMFARA CENTRAL   SD/107/ZF
# 250      ZAMFARA               ZAMFARA WEST   SD/108/ZF
# 261          FCT  FEDERAL CAPITAL TERRITORY  SD/109/FCT
#
#                                            composition  \
# 4      UMUNNEOCHI, ISUKWUATO, OHAFIA, AROCHUKWU, BENDE
# 5    UMUAHIA NORTH, UMUAHIA SOUTH, IKWUANO, ISIALA ...
# 6    ABA NORTH, ABA SOUTH, UGWUNAGBO, OBINGWA,  UKW...
# 10   ETINAN, IBESIKPO ASUTAN, IBIONO IBOM, ITU, NSI...
# 11   ABAK, ESSIEN UDIM, ETIM EKPO, IKA, IKONO, IKOT...
# 12   EASTERN OBOLO, EKET, ESIT EKET, IBENO, IKOT AB...
# 16   MADAGALI, MAIHA, MICHIKA, MUBI NORTH, MUBI SOUTH
# 17   DEMSA, GANYE, GUYUK, JADA, MAYO-BELWA, NUMAN, ...
# 18   HONG, FUFORE, SONG, YOLA NORTH, YOLA SOUTH, GERFI
# 24   ONITSHA NORTH, ONITSHA SOUTH, OYI, OGBARU, ANA...
# 25   AWKA NORTH, AWKA SOUTH, NJIKOKA, ANAOCHA, IDEM...
# 26   IHIALA, NNEWI NORTH, NNEWI SOUTH, ORUMBA SOUTH...
# 30   ALKALERI, KIRFI, BAUCHI, TAFAWA BALEWA, BOGORO...
# 31        NINGI, WARJI, DARAZO, GANJUWA, MISAU, DAMBAN
# 32   ZAKI, GAMAWA, JAMA’ARE, ITAS-GADAU, SHIRA, GIA...
# 37                                 BRASS, NEMBE, OGBIA
# 38            KOLOKUMA/OPOKUMA, SOUTHERN IJAW, YENAGOA
# 39                                   EKEREMOR, SAGBAMA
# 47   KATSINA-ALA, KONSHISHA, KWANDE, LOGO, UKUM, US...
# 48   BURUKU, GBOKO, GUMA, GWER-EAST, GWER-WEST, MAR...
# 49   ADO, AGATU, APA, OBI, OGBADIBO, OHIMINI, OJU,O...
# 54   ABADAM, GUBIO, GUZAMALA,  KUKAWA, MAGUMERI, MA...
# 55   DIKWA, JERE, KALA BALGE, MAFA, METROPOLITAN, N...
# 56   ASKIRA/UBA, BAYO, BIU, CHIBOK, DAMABOA, GWOZA,...
# 60       BEKWARRA, OBANLIKU, OBUDU, OGOJA, YALA, BIASE
# 61              ABI, BOKI, ETUNG, IKOM, OBUBRA, YAKURR
# 62   CALABAR MUNICIPAL, CALABAR SOUTH, AKAMKPA, AKP...
# 67   ETHIOPE EAST, ETHIOPE WEST, OKPE, SAPELE,UDU, ...
# 68   ANIOCHA NORTH, ANIOCHA SOUTH, IKA NORTH-EAST, ...
# 69   BOMADI, BURUTU, ISOKO NORTH, ISOKO SOUTH, PATA...
# 72                    ABAKALIKI, EBONYI, IZZI, OHAUKWU
# 73               EZZA NORTH, EZZA SOUTH, IKWO, ISHIELU
# 74   AFIKPO NORTH, AFIKPO SOUTH, IVO, OHAOZARA, ONICHA
# 77   ESAN CENTRAL, ESAN NORTH EAST, ESAN SOUTH EAST...
# 78   AKOKO EDO, ETSAKO EAST, ETSAKO CENTRAL, ETSAKO...
# 79   OREDO, ORHIONMWON, OVIA NORTH EAST, OVIA SOUTH...
# 83                IKOLE, OYE, IDO/OSI, MOBA, ILEJEMEJE
# 84   ADO EKITI, IREPODUN/IFELODUN, IJERO, EFON, EKI...
# 85   EKITI SOUTH WEST, IKERE, EMURE, ISE/ORUN, GBON...
# 90   ENUGU EAST, ENUGU NORTH, ENUGU SOUTH, ISI-UZO,...
# 91              ANINIRI, AWGU, EZEAGU, OJI RIVER, UDI
# 92   IGBO-ETITI, IGBO-EZE NORTH, IGO-EZE SOUTH, UZO...
# 97                                  AKKO, YAMALTU/DEBA
# 98                 BALANGA, BILLIRI, KALTUNGO, SHONGOM
# 99                FUNAKAYE, NAFADA, GOMBE, KWAMI,DUKKU
# 109  ABOH MBAISE, AHIAZU MBAISE, EZINIHITTE, IKEDUR...
# 110  IDEATO NORTH, IDEATO SOUTH, ISU, NJABA, NKWERE...
# 111  EHIME MBANO, IHITE/UBOMA, ISIALA MBANO, OBOWO,...
# 116  BIRNIN KUDU, BUJI, DUTSE, GWARAM, KIYAWA, JAUN...
# 117  AUYO, BIRNIWA, GURI, HADEJIA, KAUGAMA, K/HAUSA...
# 118  BABURA, GAGARA, GARKI, GWIWA, KAZAURE, MAIGATA...
# 126  KUBAU, IKARA, MAKARFI, SOBA, SABON GARI, ZARIA...
# 127  BIRNIN GWARI, GIWA, IGABI, KADUNA NORTH, KADUN...
# 128  JEMA’A, JABA, KAURA, ZANGON, KAURA, KACHIA, KA...
# 134  DALA, GWALE, DAWAKIN, GEZAWA, TARAUNI, FAGGE, ...
# 135  BICHI, SHANONO, BAGWAI, DANBATTA, MAKODA, DAWA...
# 136  ALBASU, BEBEJI, BUNKURE, DOGUWA, GAYA, KIRU, R...
# 147  DAURA, ZANGO, MAIADUA, MASHI, MANI, INGAWA, BI...
# 148  FUNTUA, FASKARI, DANJA, DANDUME, BAKORI, KANKA...
# 149  KATSINA, KAITA, JIBIA, BATSARI, SAFANA, DUTSIN...
# 153   AREWA, ARGUNGU, AUGIE, BAGUDO, DANDI, SURU, JEGA
# 154  ALEIRO, BIRNIN KEBBI, BUNZA, GWANDU, KALGO, KO...
# 155  FAKAI, NGASKI, SAKABA, SHANGA, WASAGU/DANKO, Y...
# 158       ADAVI, AJAOKUTA, OGORI/MAGONGO, OKEHI, OKENE
# 159  ANKPA, BASSA, DEKINA, IBAJI, IDAH, IGALAMELA-O...
# 160  IJUMU, KABBA, KOGI, LOKOJA, MOPAMURO, YAGBA EA...
# 165                 BARUTEN, EDU, PATIGI, KAIAMA, MORO
# 166  ASA, ILORIN EAST, ILORIN SOUTH, ILORIN WEST, OFFA
# 167    EKITI, OKE-ERO, IFELODUN, IREPODUN, ISIN,  OYUN
# 171  LAGOS ISLAND, LAGOS MAINLAND, SURULERE, APAPA,...
# 172         SHOMOLU, KOSOFE, EPE, IBEJU-LEKKI, IKORODU
# 173  AGEGE,IFAKO-IJAYE, ALIMOSHO, BADAGRY, OJO, AJE...
# 177                   AKAWANGA, NASSARAWA EGGON, WAMBA
# 178               NASSARAWA, KEFFI, KOKONA, KARU, TOTO
# 179                       LAFIA, AWE, DOMA, KEANA, OBI
# 185  BOSSO, CHACHANGA, GURARA, PAIKORO, RAFI, SHIRO...
# 186  AGWARA, BORGU, KONTOGORA, MARIGA, RIJAU, WUSHI...
# 187  AGAIE, BIDA, KATCHA, BATAGI, LAPAI, LAVUN, EDA...
# 191  IFO, EWEKORO, OBAFEMI/OWODE, ABEOKUTA NORTH, A...
# 192  SAGAMU, IKENNE, REMO NORTH, IJEBU-ODE, ODOGBOL...
# 193  IMEKO AFON, EGBADO NORTH, EGBADO SOUTH, IPOKIA...
# 196  AKOKO NORTH EAST, AKOKO NORTH WEST, AKOKO SOUT...
# 197  AKURE NORTH, AKURE SOUTH, IFEDORE, IDANRE, OND...
# 198  ILEOLUJI/OKEIGBO, ODIGBO, IRELE, OKITIPUPA, ES...
# 202  BORIPE, BOLOWADURO, IFELODUN, ILA, IFEDAYO, IR...
# 203  ATAKUNMOSA EAST, ATAKUNMOSA WEST, IFE CENTRAL,...
# 204  AYADAADE, AYEDIRE, EDE NORTH, EDE SOUTH, EGBED...
# 210  AFIJIO, AKINYELE, EGBEDA, OGO OLUWA, SURULERE,...
# 211  SAKI WEST, SAKI EAST, ATIGBO, IREPO, OLORUNSOG...
# 212  IBADAN NORTH, IBADAN NORTH EAST, IBADAN NORTH ...
# 218  LANTANG NORTH, LANTANG SOUTH, MIKANG, QUA’AN P...
# 219              BOKKOS, KANKE, MANGU, PANKSHIN, KANAM
# 220  BARKIN LADI, BASSA, JOS EAST, JOS NORTH, JOS S...
# 224  ETCHE, OMUMA, IKWERRE, OBIO AKPOR, PORT HARCOU...
# 225  OPOBO/NKORO, ANDONI, OYIGBO, TAI, ELEME, GOKAN...
# 226  ASARI-TORU, AKUKU-TORU, DEGEMA, OGBA/EGBEMA/ND...
# 229  ISA, SABON BIRNI, WURNO, GORONYO, RABAH, GADA,...
# 230  TANGAZA, BINJI, SILAME, GUDU, KWARE, WAMAKKO,S...
# 231  DANGE SHUNI, TURETA, BODINGA, SHAGARI, YABO, T...
# 235                    WUKARI, IBI, DONGA, USSA, TAKUM
# 236             SARDAUNA, KURMI, BALI, GASHAKA, GASSOL
# 237  JALINGO, YORRO, ZING, LAU, ARDO-KOLA, KARIM-LA...
# 241   BURSARI, GEIDAM,GUJBA, GULANI, TARMUWA, YUNUSARI
# 242  BADE, JAKUSKO, MACHINA, KARASUWA, NGURU, YUSUFARI
# 243            FIKA, FUNE, NANGERE, POTISKUM, DAMATURU
# 248  K/NAMODA, SHINKAFI, ZURMI, BIRNIN MAGAJI, T/MA...
# 249                        GUSAU, TSAFE, BUNGUDU, MARU
# 250             MARADUN, BAKURA, ANKA, BUKKUYUM, GUMMI
# 261  ABAJI AREA COUNCIL, GWAGWA AREA COUNCIL, KUJE ...
#
#                                       collation_centre
# 4                         COUNCIL HALL OHAFIA LGA HQS
# 5                   COUNCIL HALL UMUAHIA NORTH LGA HQS
# 6                          ABA TOWN HALL ABA SOUTH LGA
# 10                                 INEC OFFICE UYO LGA
# 11                          INEC OFFICE IKOT EKPENELGA
# 12                                EKET LGA INEC OFFICE
# 16                                            GSS MUBI
# 17                                           GSS NUMAN
# 18                                           GMMC YOLA
# 24                            ONITHA NORTH INEC OFFICE
# 25                                          AWKA SOUTH
# 26                             NNEWI NORTH INEC OFFICE
# 30                                   INEC STATE OFFICE
# 31                                              DARAZO
# 32                                               AZARE
# 37                                          INEC BRASS
# 38                                COUNCIL HALL YENAGOA
# 39                                 INEC OFFICE SAGBAMA
# 47                                         KATSINA-ALA
# 48                                            MARKURDI
# 49                                              OTUKPO
# 54                                 INEC OFFICE MONGUNO
# 55                  WAZIRI HALL MADUGURI METRO COUNCIL
# 56                              BIU LG COUNCIL CHAMBER
# 60                                   INEC OFFICE OGOJA
# 61                                    INEC OFFICE IKOM
# 62                                 CALABAR INEC OFFICE
# 67                        TOWN HALL, UGHELLI NORTH LGA
# 68                               INEC STATE H/QS ASABA
# 69                       ISOKO SOUTH COUNCIL HALL OLEH
# 72                  ABAKALIKI LGA COUNCIL HALL NKALIKI
# 73                   LG COUNCIL HALL ONUEKE EZZA SOUTH
# 74                AFIKPO NORTH LGA COUNCIL HALL AFIKPO
# 77                         SACRED HEART GIRLS’S UBIAJA
# 78                                 COUNCIL HALL, AUCHI
# 79                                INEC H/Q, BENIN CITY
# 83                ST. DAVID’S ANG. PRY. SCH. IDO-EKITI
# 84               MARY IMMACULATE GIRL’S GRAM. SCH. ADO
# 85          HOLY TRINITY PRY. SCH. ODO OJA IKERE EKITI
# 90                         ENUGU NORTH LG COUNCIL HALL
# 91                                AWGU LG COUNCIL HALL
# 92                                      NSUKKA LG HALL
# 97                               GOVT. TECH. SCH. KUMO
# 98                                      GGASS KALTUNGO
# 99                                      GSS MALAM SIDI
# 109                      OWERRI MUNICIPAL COUNCIL HALL
# 110                              ORLU LGA COUNCIL HALL
# 111                            OKIGWE LGA COUNCIL HALL
# 116                            DUTSE MUNICIPAL COUNCIL
# 117                             HADEJIA LG SECRETERIAT
# 118                            GUMEL LOCAL SECRETERIAT
# 126                              INEC OFFICE ZARIA LGA
# 127                       KADUNA NORTH COUNCIL CHAMBER
# 128                             INEC OFFICE JEMA'A LGA
# 134                         KANO MUNICIPAL SECRETARIAT
# 135                                    BICHI LGA SECT.
# 136                               KANO LGA SECRETARIAT
# 147                                  INEC OFFICE DAURA
# 148                                 INEC OFFICE FUNTUA
# 149                       INEC OFFICE KATSINA STATE HQ
# 153                              KAMBA LGA SECRETARIAT
# 154                        BIRNI KEBBI LGA INEC OFFICE
# 155                               ZURU LGA INEC OFFICE
# 158                              LGA SECRETARIAT OKENE
# 159                                          INEC IDAH
# 160                                 INEC OFFICE LOKOJA
# 165                           MORO-LGA COUNCIL CHAMBER
# 166                                 INEC OFFICE ILORIN
# 167                         IRPODUN LG COUNCIL CHAMBER
# 171                             CITY HALL LAGOS ISLAND
# 172                 COUNCIL HALL SOMOLU LG SECRETARIAT
# 173               COUNCIL CHAMBER IKEJA LG SECRETARIAT
# 177                        VIP COUCIL CHAMBERS AKWANGA
# 178        MAIN AUDITORIUM NAS. STATE UNIVERSITY KEFFI
# 179                  IBRAHIM ABACHA YOUTH CENTRE LAFIA
# 185                               COLLEG OF EDU. MUNYA
# 186                      GOVT. TECH. COLLEGE KONTAGORA
# 187                                 GOVT. COLLEGE BIDA
# 191                       CENTENARY HALL AKE, ABEOKUTA
# 192                                TOWN HALL IJEBU ODE
# 193                             ARONNA TOWN HALL ILARO
# 196                                     MAPO HALL, OWO
# 197                    ST. PETER’S UNITY SCHOOL, AKURE
# 198                    STELLA MARIS COLLEGE OKITIPUPA
# 202                           OSOGBO CITY HALL, OSOGBO
# 203                        ILESA GRAMMER SCHOOL, ILESA
# 204                      BAPTIST HIGH SCHOOL ADEKE IWO
# 210                INEC OFFICE AKINYELE LG SEC. MONIYA
# 211                              LG SEC. ISEYIN ISEYIN
# 212            INEC OFFICE IBADAN NORTH LG SEC. IBADAN
# 218                            SHENDAM LG COUNCIL SEC.
# 219                           PANKSHIN LG COUNCIL SEC.
# 220                          JOS NORTH LG COUNCIL SEC.
# 224     PORT HARCORUT CITY COUNCIL HALL, PORT HARCOURT
# 225                 SWANU-FINIMA NWIKA CONF. HALL BORI
# 226       AHOADA EAST LOCAL GOVT. COUNCIL HALL, AHOADA
# 229                      GWADABAWA LGA CONFERENCE ROOM
# 230  SOKOTO NORTH LOCAL GOVT. COUNCIL CONFERENENCE ...
# 231                       BODINGA LGA  CONFERENCE ROOM
# 235                           WUKARI RECREATION CENTRE
# 236                               BALI LGA SECRETARIAT
# 237                            JALINGO LGA SECRETARIAT
# 241                       FEDERAL POLYTECHNIC DAMATURU
# 242                        COLLEGE OF EDUCATION GASHUA
# 243                       FEDERAL COLLEGE OF EDUCATION
# 248                           INEC OFFICE KAURA NAMODA
# 249                                  INEC OFFICE GUSAU
# 250                          INEC OFFICE TALATA MAFARA
# 261                                    INEC OFFICE FCT

# %% [markdown]
# Above, I see that the Adamawa state senatorial districts are stored under "Akwa Ibom". The same is true for a couple of other states.
#
# **That's a flag**
#
# I will correctc this by manually assigning the correct state names to the mismatched senatorial districts.

# %%
# Fix mismatched state names manually
fixes = {
    16: "ADAMAWA",
    17: "ADAMAWA",
    18: "ADAMAWA",
    47: "BENUE",
    48: "BENUE",
    49: "BENUE",
    177: "NASARAWA",
    178: "NASARAWA",
    179: "NASARAWA",
}

# Apply corrections
for idx, correct_state in fixes.items():
    clean_df.at[idx, "state"] = correct_state

# Now let's check again
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

display(clean_df)
# Out:
#            state        senatorial_district        code  \
# 4           ABIA                ABIA NORTH    SD/001/AB
# 5           ABIA              ABIA CENTRAL    SD/002/AB
# 6           ABIA                ABIA SOUTH    SD/003/AB
# 10     AKWA IBOM       AKWA IBOM NORTH EAST   SD/007/AK
# 11     AKWA IBOM      AKWA IBOM NORTH WEST    SD/008/AK
# 12     AKWA IBOM           AKWA IBOM SOUTH    SD/009/AK
# 16       ADAMAWA              ADAMAWA NORTH   SD/004/AD
# 17       ADAMAWA             ADAMAWA SOUTH    SD/005/AD
# 18       ADAMAWA            ADAMAWA CENTRAL   SD/006/AD
# 24      ANAMBRA              ANAMBRA NORTH    SD/010/AN
# 25      ANAMBRA            ANAMBRA CENTRAL    SD/011/AN
# 26      ANAMBRA              ANAMBRA SOUTH    SD/012/AN
# 30        BAUCHI              BAUCHI SOUTH    SD/013/BA
# 31        BAUCHI            BAUCHI CENTRAL    SD/014/BA
# 32        BAUCHI              BAUCHI NORTH    SD/015/BA
# 37       BAYELSA               BAYELSA EAST   SD/016/BY
# 38       BAYELSA           BAYELSA CENTRAL    SD/017/BY
# 39       BAYELSA              BAYELSA WEST    SD/018/BY
# 47         BENUE         BENUE NORTH  EAST    SD/019/BN
# 48         BENUE           BENUE NORTH WEST   SD/020/BN
# 49         BENUE                BENUE SOUTH   SD/021/BN
# 54         BORNO                BORNO NORTH   SD/022/BO
# 55         BORNO              BORNO CENTRAL   SD/023/BO
# 56         BORNO                BORNO SOUTH   SD/024/BO
# 60   CROSS RIVER          CROSS RIVER NORTH   SD/025/CR
# 61   CROSS RIVER        CROSS RIVER CENTRAL   SD/026/CR
# 62   CROSS RIVER          CROSS RIVER SOUTH   SD/027/CR
# 67         DELTA              DELTA CENTRAL   SD/028/DT
# 68         DELTA                DELTA NORTH   SD/029/DT
# 69         DELTA                DELTA SOUTH   SD/030/DT
# 72        EBONYI               EBONYI NORTH   SD/031/EB
# 73        EBONYI             EBONYI CENTRAL   SD/032/EB
# 74        EBONYI              EBONYI  SOUTH   SD/033/EB
# 77           EDO                EDO CENTRAL   SD/034/ED
# 78           EDO                  EDO NORTH   SD/035/ED
# 79           EDO                 EDO  SOUTH   SD/036/ED
# 83         EKITI                EKITI NORTH   SD/037/EK
# 84         EKITI              EKITI CENTRAL   SD/038/EK
# 85         EKITI               EKITI  SOUTH   SD/039/EK
# 90         ENUGU                 ENUGU EAST   SD/040/EN
# 91         ENUGU                 ENUGU WEST   SD/041/EN
# 92         ENUGU               ENUGU  NORTH   SD/042/EN
# 97         GOMBE              GOMBE CENTRAL   SD/043/GM
# 98         GOMBE                GOMBE SOUTH   SD/044/GM
# 99         GOMBE              GOMBE NORTH     SD/045/GM
# 109          IMO                   IMO EAST   SD/046/IM
# 110          IMO                   IMO WEST   SD/047/IM
# 111          IMO                IMO NORTH     SD/048/IM
# 116       JIGAWA        JIGAWA SOUTH – WEST   SD/049/JG
# 117       JIGAWA        JIGAWA NORTH – EAST   SD/050/JG
# 118       JIGAWA       JIGAWA NORTH - WEST    SD/051/JG
# 126       KADUNA               KADUNA NORTH   SD/052/KD
# 127       KADUNA             KADUNA CENTRAL   SD/053/KD
# 128       KADUNA               KADUNA SOUTH   SD/054/KD
# 134         KANO               KANO CENTRAL   SD/055/KN
# 135         KANO                 KANO NORTH   SD/056/KN
# 136         KANO                KANO  SOUTH   SD/057/KN
# 147      KATSINA              KATSINA NORTH   SD/058/KT
# 148      KATSINA              KATSINA SOUTH   SD/059/KT
# 149      KATSINA           KATSINA CENTRAL    SD/060/KT
# 153        KEBBI                KEBBI NORTH   SD/061/KB
# 154        KEBBI              KEBBI CENTRAL   SD/062/KB
# 155        KEBBI                KEBBI SOUTH   SD/063/KB
# 158         KOGI               KOGI CENTRAL   SD/064/KG
# 159         KOGI                  KOGI EAST   SD/065/KG
# 160         KOGI                  KOGI WEST   SD/066/KG
# 165        KWARA                KWARA NORTH   SD/067/KW
# 166        KWARA              KWARA CENTRAL   SD/068/KW
# 167        KWARA                KWARA SOUTH   SD/069/KW
# 171        LAGOS              LAGOS CENTRAL   SD/070/LA
# 172        LAGOS                 LAGOS EAST   SD/071/LA
# 173        LAGOS                LAGOS  WEST   SD/072/LA
# 177     NASARAWA            NASSARAWA NORTH   SD/073/NW
# 178     NASARAWA             NASSARAWA WEST   SD/074/NW
# 179     NASARAWA           NASSARAWA  SOUTH   SD/075/NW
# 185        NIGER                 NIGER EAST   SD/076/NG
# 186        NIGER                NIGER NORTH   SD/077/NG
# 187        NIGER                NIGER SOUTH   SD/078/NG
# 191         OGUN               OGUN CENTRAL   SD/079/OG
# 192         OGUN                  OGUN EAST   SD/080/OG
# 193         OGUN                  OGUN WEST   SD/081/OG
# 196         ONDO                 ONDO NORTH   SD/082/OD
# 197         ONDO               ONDO CENTRAL   SD/083/OD
# 198         ONDO                 ONDO SOUTH   SD/084/OD
# 202         OSUN               OSUN CENTRAL   SD/085/OS
# 203         OSUN                  OSUN EAST   SD/086/OS
# 204         OSUN                  OSUN WEST   SD/087/OS
# 210          OYO                OYO CENTRAL   SD/088/OY
# 211          OYO                  OYO NORTH   SD/089/OY
# 212          OYO                  OYO SOUTH   SD/090/OY
# 218      PLATEAU              PLATEAU SOUTH   SD/091/PL
# 219      PLATEAU            PLATEAU CENTRAL   SD/092/PL
# 220      PLATEAU              PLATEAU NORTH   SD/093/PL
# 224       RIVERS                RIVERS EAST   SD/094/RV
# 225       RIVERS          RIVERS SOUTH EAST   SD/095/RV
# 226       RIVERS                RIVERS WEST   SD/096/RV
# 229       SOKOTO                SOKOTO EAST   SD/097/SO
# 230       SOKOTO               SOKOTO NORTH   SD/098/SO
# 231       SOKOTO               SOKOTO SOUTH   SD/099/SO
# 235       TARABA               TARABA SOUTH   SD/100/TR
# 236       TARABA             TARABA CENTRAL   SD/101/TR
# 237       TARABA               TARABA NORTH   SD/102/TR
# 241         YOBE                  YOBE EAST   SD/103/YB
# 242         YOBE                 YOBE NORTH   SD/104/YB
# 243         YOBE                 YOBE SOUTH   SD/105/YB
# 248      ZAMFARA              ZAMFARA NORTH   SD/106/ZF
# 249      ZAMFARA            ZAMFARA CENTRAL   SD/107/ZF
# 250      ZAMFARA               ZAMFARA WEST   SD/108/ZF
# 261          FCT  FEDERAL CAPITAL TERRITORY  SD/109/FCT
#
#                                            composition  \
# 4      UMUNNEOCHI, ISUKWUATO, OHAFIA, AROCHUKWU, BENDE
# 5    UMUAHIA NORTH, UMUAHIA SOUTH, IKWUANO, ISIALA ...
# 6    ABA NORTH, ABA SOUTH, UGWUNAGBO, OBINGWA,  UKW...
# 10   ETINAN, IBESIKPO ASUTAN, IBIONO IBOM, ITU, NSI...
# 11   ABAK, ESSIEN UDIM, ETIM EKPO, IKA, IKONO, IKOT...
# 12   EASTERN OBOLO, EKET, ESIT EKET, IBENO, IKOT AB...
# 16   MADAGALI, MAIHA, MICHIKA, MUBI NORTH, MUBI SOUTH
# 17   DEMSA, GANYE, GUYUK, JADA, MAYO-BELWA, NUMAN, ...
# 18   HONG, FUFORE, SONG, YOLA NORTH, YOLA SOUTH, GERFI
# 24   ONITSHA NORTH, ONITSHA SOUTH, OYI, OGBARU, ANA...
# 25   AWKA NORTH, AWKA SOUTH, NJIKOKA, ANAOCHA, IDEM...
# 26   IHIALA, NNEWI NORTH, NNEWI SOUTH, ORUMBA SOUTH...
# 30   ALKALERI, KIRFI, BAUCHI, TAFAWA BALEWA, BOGORO...
# 31        NINGI, WARJI, DARAZO, GANJUWA, MISAU, DAMBAN
# 32   ZAKI, GAMAWA, JAMA’ARE, ITAS-GADAU, SHIRA, GIA...
# 37                                 BRASS, NEMBE, OGBIA
# 38            KOLOKUMA/OPOKUMA, SOUTHERN IJAW, YENAGOA
# 39                                   EKEREMOR, SAGBAMA
# 47   KATSINA-ALA, KONSHISHA, KWANDE, LOGO, UKUM, US...
# 48   BURUKU, GBOKO, GUMA, GWER-EAST, GWER-WEST, MAR...
# 49   ADO, AGATU, APA, OBI, OGBADIBO, OHIMINI, OJU,O...
# 54   ABADAM, GUBIO, GUZAMALA,  KUKAWA, MAGUMERI, MA...
# 55   DIKWA, JERE, KALA BALGE, MAFA, METROPOLITAN, N...
# 56   ASKIRA/UBA, BAYO, BIU, CHIBOK, DAMABOA, GWOZA,...
# 60       BEKWARRA, OBANLIKU, OBUDU, OGOJA, YALA, BIASE
# 61              ABI, BOKI, ETUNG, IKOM, OBUBRA, YAKURR
# 62   CALABAR MUNICIPAL, CALABAR SOUTH, AKAMKPA, AKP...
# 67   ETHIOPE EAST, ETHIOPE WEST, OKPE, SAPELE,UDU, ...
# 68   ANIOCHA NORTH, ANIOCHA SOUTH, IKA NORTH-EAST, ...
# 69   BOMADI, BURUTU, ISOKO NORTH, ISOKO SOUTH, PATA...
# 72                    ABAKALIKI, EBONYI, IZZI, OHAUKWU
# 73               EZZA NORTH, EZZA SOUTH, IKWO, ISHIELU
# 74   AFIKPO NORTH, AFIKPO SOUTH, IVO, OHAOZARA, ONICHA
# 77   ESAN CENTRAL, ESAN NORTH EAST, ESAN SOUTH EAST...
# 78   AKOKO EDO, ETSAKO EAST, ETSAKO CENTRAL, ETSAKO...
# 79   OREDO, ORHIONMWON, OVIA NORTH EAST, OVIA SOUTH...
# 83                IKOLE, OYE, IDO/OSI, MOBA, ILEJEMEJE
# 84   ADO EKITI, IREPODUN/IFELODUN, IJERO, EFON, EKI...
# 85   EKITI SOUTH WEST, IKERE, EMURE, ISE/ORUN, GBON...
# 90   ENUGU EAST, ENUGU NORTH, ENUGU SOUTH, ISI-UZO,...
# 91              ANINIRI, AWGU, EZEAGU, OJI RIVER, UDI
# 92   IGBO-ETITI, IGBO-EZE NORTH, IGO-EZE SOUTH, UZO...
# 97                                  AKKO, YAMALTU/DEBA
# 98                 BALANGA, BILLIRI, KALTUNGO, SHONGOM
# 99                FUNAKAYE, NAFADA, GOMBE, KWAMI,DUKKU
# 109  ABOH MBAISE, AHIAZU MBAISE, EZINIHITTE, IKEDUR...
# 110  IDEATO NORTH, IDEATO SOUTH, ISU, NJABA, NKWERE...
# 111  EHIME MBANO, IHITE/UBOMA, ISIALA MBANO, OBOWO,...
# 116  BIRNIN KUDU, BUJI, DUTSE, GWARAM, KIYAWA, JAUN...
# 117  AUYO, BIRNIWA, GURI, HADEJIA, KAUGAMA, K/HAUSA...
# 118  BABURA, GAGARA, GARKI, GWIWA, KAZAURE, MAIGATA...
# 126  KUBAU, IKARA, MAKARFI, SOBA, SABON GARI, ZARIA...
# 127  BIRNIN GWARI, GIWA, IGABI, KADUNA NORTH, KADUN...
# 128  JEMA’A, JABA, KAURA, ZANGON, KAURA, KACHIA, KA...
# 134  DALA, GWALE, DAWAKIN, GEZAWA, TARAUNI, FAGGE, ...
# 135  BICHI, SHANONO, BAGWAI, DANBATTA, MAKODA, DAWA...
# 136  ALBASU, BEBEJI, BUNKURE, DOGUWA, GAYA, KIRU, R...
# 147  DAURA, ZANGO, MAIADUA, MASHI, MANI, INGAWA, BI...
# 148  FUNTUA, FASKARI, DANJA, DANDUME, BAKORI, KANKA...
# 149  KATSINA, KAITA, JIBIA, BATSARI, SAFANA, DUTSIN...
# 153   AREWA, ARGUNGU, AUGIE, BAGUDO, DANDI, SURU, JEGA
# 154  ALEIRO, BIRNIN KEBBI, BUNZA, GWANDU, KALGO, KO...
# 155  FAKAI, NGASKI, SAKABA, SHANGA, WASAGU/DANKO, Y...
# 158       ADAVI, AJAOKUTA, OGORI/MAGONGO, OKEHI, OKENE
# 159  ANKPA, BASSA, DEKINA, IBAJI, IDAH, IGALAMELA-O...
# 160  IJUMU, KABBA, KOGI, LOKOJA, MOPAMURO, YAGBA EA...
# 165                 BARUTEN, EDU, PATIGI, KAIAMA, MORO
# 166  ASA, ILORIN EAST, ILORIN SOUTH, ILORIN WEST, OFFA
# 167    EKITI, OKE-ERO, IFELODUN, IREPODUN, ISIN,  OYUN
# 171  LAGOS ISLAND, LAGOS MAINLAND, SURULERE, APAPA,...
# 172         SHOMOLU, KOSOFE, EPE, IBEJU-LEKKI, IKORODU
# 173  AGEGE,IFAKO-IJAYE, ALIMOSHO, BADAGRY, OJO, AJE...
# 177                   AKAWANGA, NASSARAWA EGGON, WAMBA
# 178               NASSARAWA, KEFFI, KOKONA, KARU, TOTO
# 179                       LAFIA, AWE, DOMA, KEANA, OBI
# 185  BOSSO, CHACHANGA, GURARA, PAIKORO, RAFI, SHIRO...
# 186  AGWARA, BORGU, KONTOGORA, MARIGA, RIJAU, WUSHI...
# 187  AGAIE, BIDA, KATCHA, BATAGI, LAPAI, LAVUN, EDA...
# 191  IFO, EWEKORO, OBAFEMI/OWODE, ABEOKUTA NORTH, A...
# 192  SAGAMU, IKENNE, REMO NORTH, IJEBU-ODE, ODOGBOL...
# 193  IMEKO AFON, EGBADO NORTH, EGBADO SOUTH, IPOKIA...
# 196  AKOKO NORTH EAST, AKOKO NORTH WEST, AKOKO SOUT...
# 197  AKURE NORTH, AKURE SOUTH, IFEDORE, IDANRE, OND...
# 198  ILEOLUJI/OKEIGBO, ODIGBO, IRELE, OKITIPUPA, ES...
# 202  BORIPE, BOLOWADURO, IFELODUN, ILA, IFEDAYO, IR...
# 203  ATAKUNMOSA EAST, ATAKUNMOSA WEST, IFE CENTRAL,...
# 204  AYADAADE, AYEDIRE, EDE NORTH, EDE SOUTH, EGBED...
# 210  AFIJIO, AKINYELE, EGBEDA, OGO OLUWA, SURULERE,...
# 211  SAKI WEST, SAKI EAST, ATIGBO, IREPO, OLORUNSOG...
# 212  IBADAN NORTH, IBADAN NORTH EAST, IBADAN NORTH ...
# 218  LANTANG NORTH, LANTANG SOUTH, MIKANG, QUA’AN P...
# 219              BOKKOS, KANKE, MANGU, PANKSHIN, KANAM
# 220  BARKIN LADI, BASSA, JOS EAST, JOS NORTH, JOS S...
# 224  ETCHE, OMUMA, IKWERRE, OBIO AKPOR, PORT HARCOU...
# 225  OPOBO/NKORO, ANDONI, OYIGBO, TAI, ELEME, GOKAN...
# 226  ASARI-TORU, AKUKU-TORU, DEGEMA, OGBA/EGBEMA/ND...
# 229  ISA, SABON BIRNI, WURNO, GORONYO, RABAH, GADA,...
# 230  TANGAZA, BINJI, SILAME, GUDU, KWARE, WAMAKKO,S...
# 231  DANGE SHUNI, TURETA, BODINGA, SHAGARI, YABO, T...
# 235                    WUKARI, IBI, DONGA, USSA, TAKUM
# 236             SARDAUNA, KURMI, BALI, GASHAKA, GASSOL
# 237  JALINGO, YORRO, ZING, LAU, ARDO-KOLA, KARIM-LA...
# 241   BURSARI, GEIDAM,GUJBA, GULANI, TARMUWA, YUNUSARI
# 242  BADE, JAKUSKO, MACHINA, KARASUWA, NGURU, YUSUFARI
# 243            FIKA, FUNE, NANGERE, POTISKUM, DAMATURU
# 248  K/NAMODA, SHINKAFI, ZURMI, BIRNIN MAGAJI, T/MA...
# 249                        GUSAU, TSAFE, BUNGUDU, MARU
# 250             MARADUN, BAKURA, ANKA, BUKKUYUM, GUMMI
# 261  ABAJI AREA COUNCIL, GWAGWA AREA COUNCIL, KUJE ...
#
#                                       collation_centre
# 4                         COUNCIL HALL OHAFIA LGA HQS
# 5                   COUNCIL HALL UMUAHIA NORTH LGA HQS
# 6                          ABA TOWN HALL ABA SOUTH LGA
# 10                                 INEC OFFICE UYO LGA
# 11                          INEC OFFICE IKOT EKPENELGA
# 12                                EKET LGA INEC OFFICE
# 16                                            GSS MUBI
# 17                                           GSS NUMAN
# 18                                           GMMC YOLA
# 24                            ONITHA NORTH INEC OFFICE
# 25                                          AWKA SOUTH
# 26                             NNEWI NORTH INEC OFFICE
# 30                                   INEC STATE OFFICE
# 31                                              DARAZO
# 32                                               AZARE
# 37                                          INEC BRASS
# 38                                COUNCIL HALL YENAGOA
# 39                                 INEC OFFICE SAGBAMA
# 47                                         KATSINA-ALA
# 48                                            MARKURDI
# 49                                              OTUKPO
# 54                                 INEC OFFICE MONGUNO
# 55                  WAZIRI HALL MADUGURI METRO COUNCIL
# 56                              BIU LG COUNCIL CHAMBER
# 60                                   INEC OFFICE OGOJA
# 61                                    INEC OFFICE IKOM
# 62                                 CALABAR INEC OFFICE
# 67                        TOWN HALL, UGHELLI NORTH LGA
# 68                               INEC STATE H/QS ASABA
# 69                       ISOKO SOUTH COUNCIL HALL OLEH
# 72                  ABAKALIKI LGA COUNCIL HALL NKALIKI
# 73                   LG COUNCIL HALL ONUEKE EZZA SOUTH
# 74                AFIKPO NORTH LGA COUNCIL HALL AFIKPO
# 77                         SACRED HEART GIRLS’S UBIAJA
# 78                                 COUNCIL HALL, AUCHI
# 79                                INEC H/Q, BENIN CITY
# 83                ST. DAVID’S ANG. PRY. SCH. IDO-EKITI
# 84               MARY IMMACULATE GIRL’S GRAM. SCH. ADO
# 85          HOLY TRINITY PRY. SCH. ODO OJA IKERE EKITI
# 90                         ENUGU NORTH LG COUNCIL HALL
# 91                                AWGU LG COUNCIL HALL
# 92                                      NSUKKA LG HALL
# 97                               GOVT. TECH. SCH. KUMO
# 98                                      GGASS KALTUNGO
# 99                                      GSS MALAM SIDI
# 109                      OWERRI MUNICIPAL COUNCIL HALL
# 110                              ORLU LGA COUNCIL HALL
# 111                            OKIGWE LGA COUNCIL HALL
# 116                            DUTSE MUNICIPAL COUNCIL
# 117                             HADEJIA LG SECRETERIAT
# 118                            GUMEL LOCAL SECRETERIAT
# 126                              INEC OFFICE ZARIA LGA
# 127                       KADUNA NORTH COUNCIL CHAMBER
# 128                             INEC OFFICE JEMA'A LGA
# 134                         KANO MUNICIPAL SECRETARIAT
# 135                                    BICHI LGA SECT.
# 136                               KANO LGA SECRETARIAT
# 147                                  INEC OFFICE DAURA
# 148                                 INEC OFFICE FUNTUA
# 149                       INEC OFFICE KATSINA STATE HQ
# 153                              KAMBA LGA SECRETARIAT
# 154                        BIRNI KEBBI LGA INEC OFFICE
# 155                               ZURU LGA INEC OFFICE
# 158                              LGA SECRETARIAT OKENE
# 159                                          INEC IDAH
# 160                                 INEC OFFICE LOKOJA
# 165                           MORO-LGA COUNCIL CHAMBER
# 166                                 INEC OFFICE ILORIN
# 167                         IRPODUN LG COUNCIL CHAMBER
# 171                             CITY HALL LAGOS ISLAND
# 172                 COUNCIL HALL SOMOLU LG SECRETARIAT
# 173               COUNCIL CHAMBER IKEJA LG SECRETARIAT
# 177                        VIP COUCIL CHAMBERS AKWANGA
# 178        MAIN AUDITORIUM NAS. STATE UNIVERSITY KEFFI
# 179                  IBRAHIM ABACHA YOUTH CENTRE LAFIA
# 185                               COLLEG OF EDU. MUNYA
# 186                      GOVT. TECH. COLLEGE KONTAGORA
# 187                                 GOVT. COLLEGE BIDA
# 191                       CENTENARY HALL AKE, ABEOKUTA
# 192                                TOWN HALL IJEBU ODE
# 193                             ARONNA TOWN HALL ILARO
# 196                                     MAPO HALL, OWO
# 197                    ST. PETER’S UNITY SCHOOL, AKURE
# 198                    STELLA MARIS COLLEGE OKITIPUPA
# 202                           OSOGBO CITY HALL, OSOGBO
# 203                        ILESA GRAMMER SCHOOL, ILESA
# 204                      BAPTIST HIGH SCHOOL ADEKE IWO
# 210                INEC OFFICE AKINYELE LG SEC. MONIYA
# 211                              LG SEC. ISEYIN ISEYIN
# 212            INEC OFFICE IBADAN NORTH LG SEC. IBADAN
# 218                            SHENDAM LG COUNCIL SEC.
# 219                           PANKSHIN LG COUNCIL SEC.
# 220                          JOS NORTH LG COUNCIL SEC.
# 224     PORT HARCORUT CITY COUNCIL HALL, PORT HARCOURT
# 225                 SWANU-FINIMA NWIKA CONF. HALL BORI
# 226       AHOADA EAST LOCAL GOVT. COUNCIL HALL, AHOADA
# 229                      GWADABAWA LGA CONFERENCE ROOM
# 230  SOKOTO NORTH LOCAL GOVT. COUNCIL CONFERENENCE ...
# 231                       BODINGA LGA  CONFERENCE ROOM
# 235                           WUKARI RECREATION CENTRE
# 236                               BALI LGA SECRETARIAT
# 237                            JALINGO LGA SECRETARIAT
# 241                       FEDERAL POLYTECHNIC DAMATURU
# 242                        COLLEGE OF EDUCATION GASHUA
# 243                       FEDERAL COLLEGE OF EDUCATION
# 248                           INEC OFFICE KAURA NAMODA
# 249                                  INEC OFFICE GUSAU
# 250                          INEC OFFICE TALATA MAFARA
# 261                                    INEC OFFICE FCT

# %%
# and finally a double-check of the summary

summary = clean_df.groupby("state")["senatorial_district"].count().reset_index()
summary = summary.rename(columns={"senatorial_district": "num_districts"})
display(summary)
# Out:
#           state  num_districts
# 0      ANAMBRA               3
# 1          ABIA              3
# 2       ADAMAWA              3
# 3     AKWA IBOM              3
# 4        BAUCHI              3
# 5       BAYELSA              3
# 6         BENUE              3
# 7         BORNO              3
# 8   CROSS RIVER              3
# 9         DELTA              3
# 10       EBONYI              3
# 11          EDO              3
# 12        EKITI              3
# 13        ENUGU              3
# 14          FCT              1
# 15        GOMBE              3
# 16          IMO              3
# 17       JIGAWA              3
# 18       KADUNA              3
# 19         KANO              3
# 20      KATSINA              3
# 21        KEBBI              3
# 22         KOGI              3
# 23        KWARA              3
# 24        LAGOS              3
# 25     NASARAWA              3
# 26        NIGER              3
# 27         OGUN              3
# 28         ONDO              3
# 29         OSUN              3
# 30          OYO              3
# 31      PLATEAU              3
# 32       RIVERS              3
# 33       SOKOTO              3
# 34       TARABA              3
# 35         YOBE              3
# 36      ZAMFARA              3

# %% [markdown]
# That worked. The new cleaned datasets are saved as "cleaned_LGA_SEN.csv" and "cleaned_LGA_SEN.xlsx" under the same folder.

# %% [markdown]
# #### Task 2 - 5
# I will use Python to automate the data joining, aggregration, and exporting process. First, confirm/install deps:
#
# `pip install geopandas`

# %% [markdown]
# Next, I created a `join_data.py` file inside the "Assignment 1" folder. This file contains the script that preprocesses the datasets and consolidates them for use by our QGIS project.
#
# The below command runs the script:
#
# `cd "C:\Users\USER\Desktop\eHealthOrg\Assignment 1"`
#
# `python join_data.py`

# %% [markdown]
# #### Task 6 - 7
# Delivered as required.
